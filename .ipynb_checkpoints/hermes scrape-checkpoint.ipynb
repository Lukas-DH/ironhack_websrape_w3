# %%
import json
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
# catagories = ['COLLECTIONPE','MENSHOES','PRECOLLECTIONPE']
catagories = [i for i in pimCode['pimCode']]

# %%
cat_url = 'https://bck.hermes.com/categories?locale=uk_en'

# %%
results_cat_url = requests.get(cat_url).json()

# %%
pimCode = pd.json_normalize(results_cat_url['children'])

# %%
pd.json_normalize(results_cat_url)
# Out:
#     tid                 name                        path    pimCode  \
# 0  1481  Catalogue ecommerce  /uk/en/taxonomy/term/1481/  mastereco
#
#                                             children  \
# 0  [{'tid': '1486', 'name': 'Women', 'path': '/uk...
#
#                                   children_editorial edito.childrens
# 0  [{'tid': '337176', 'name': 'Join Hermès', 'pat...              []

# %%
pd.json_normalize(pimCode.children[1])['pimCode']
# Out:
# 0               MENREADYTOWEAR
# 1                      MENTIES
# 2                     MENSHOES
# 3     MENBAGSSMALLLEATHERGOODS
# 4                     MENBELTS
# 5               MENACCESSORIES
# 6                   MENJEWELRY
# 7                MENFRAGRANCES
# 8                   MENWATCHES
# 9                       MENAWH
# 10                    MENBEACH
# Name: pimCode, dtype: object

# %%
[i for i in pimCode['pimCode']]
# Out:
# ['WOMEN',
#  'MEN',
#  'HOME',
#  'BIJOUTERIE',
#  'JEWELRY',
#  'WATCHES',
#  'FRAGRANCES',
#  'SHOES',
#  'BAGSSMALLLEATHERGOODS',
#  'SILKSCARVESETC',
#  'EQUESTRIAN',
#  'TIES',
#  'PetitH',
#  'READINGWRITING',
#  'BABYGIFTS']

# %%
import time
df_final = pd.DataFrame()


for cats in catagories:
    i = 0
    df_shape = 1 , 1
    while df_shape != df_final.shape:  
        df_shape = df_final.shape
        url = f'https://bck.hermes.com/product?urlParams=fh_view_size=36%26country=uk%26fh_location=--%252Fcategories%253C%257B{cats.lower()}%257D%26fh_start_index={36*1 if i<2 else 36*(i-1)}&locale=uk_en&category={cats}&sort=relevance&offset={36*1 if i<2 else 36*(i-1)}'
        results = requests.get(url).json()
        df = pd.json_normalize(results['products'])
        df['pimCode'] = cats
        df_final = df_final.append(df)
        time.sleep(0.1)
        i += 1
    print(cats)
    print(df_final.shape)
# Out:
# WOMEN
# (3140, 22)
# MEN
# (5157, 22)
# HOME
# (6059, 22)
# BIJOUTERIE
# (6167, 22)
# JEWELRY
# (6814, 22)
# WATCHES
# (7024, 22)
# FRAGRANCES
# (7172, 22)
# SHOES
# (7645, 22)
# BAGSSMALLLEATHERGOODS
# (8338, 22)
# SILKSCARVESETC
# (8872, 22)
# EQUESTRIAN
# (8944, 22)
# TIES
# (9325, 22)
# PetitH
# (9524, 22)
# READINGWRITING
# (9629, 22)
# BABYGIFTS
# (9695, 22)

# %%
df_final.keys()
# Out:
# Index(['sku', 'title', 'productCode', 'perso_product_type', 'assets',
#        'moreColors', 'size', 'massVolume', 'avgColor', 'departmentCode',
#        'familyCode', 'divisionCode', 'price', 'url', 'slug', 'hasStock',
#        'hasStockRetail', 'hasStockOrHasStockRetail', 'personalize',
#        'stock.ecom', 'stock.retail'],
#       dtype='object')

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\lukas\\Documents\\Ironhack\\01_GitHub\\ironhack_websrape_w3'

# %%
df_final.to_csv('all_hermes.csv')

# %%
df_final.sample(3)
# Out:
#                sku                 title productCode perso_product_type  \
# 2    H300001FO4ZGM  Clic Clac H bracelet        F031               None
# 1      H646108T 10            On Air tie        T053               None
# 14  H192209Z 5T360         Trail sneaker        Z857               None
#
#                                                assets moreColors         size  \
# 2   [{'url': '//assets.hermes.com/is/image/hermesp...      False           GM
# 1   [{'url': '//assets.hermes.com/is/image/hermesp...      False  SANS_TAILLE
# 14  [{'url': '//assets.hermes.com/is/image/hermesp...      False           36
#
#    massVolume avgColor departmentCode  ...  price  \
# 2        None     blue              F  ...  570.0
# 1        None   yellow              T  ...  170.0
# 14       None     pink              Z  ...  780.0
#
#                                             url                  slug  \
# 2   /product/clic-clac-h-bracelet-H300001FO4ZGM  clic-clac-h-bracelet
# 1               /product/on-air-tie-H646108Tv10            on-air-tie
# 14        /product/trail-sneaker-H192209Zv5T360         trail-sneaker
#
#    hasStock hasStockRetail hasStockOrHasStockRetail personalize stock.ecom  \
# 2      True          False                    False       False       True
# 1      True          False                    False       False       True
# 14     True          False                    False       False       True
#
#    stock.retail pimCode
# 2         False   WOMEN
# 1         False     MEN
# 14        False   WOMEN
#
# [3 rows x 22 columns]

# %%
df_final
# Out:
#                sku                                            title  \
# 0   H102536B 00048                         Osmose ring, large model
# 1      H243507S 08  Couvertures et Tenues de Jour Bandana shawl 140
# 2      H003433S 04                          Plumes en Fete scarf 90
# 3   H201134Z 90355                                     Amica sandal
# 4   H201158Z 02350                                      Oran sandal
# ..             ...                                              ...
# 17     H103140M 03                          Adada Dots baby bunting
# 18     H103139M 03                          Adada Dots sleeping bag
# 19     H103135M 01                         Cheval a Bascule blanket
# 20     H103163M 01                     Adada Dots case, large model
# 21     H103136M 01                               Adada Dots blanket
#
#    productCode perso_product_type  \
# 0         B652               None
# 1         S021               None
# 2         S011               None
# 3         Z854               None
# 4         Z854               None
# ..         ...                ...
# 17        M106               None
# 18        M106               None
# 19        M106               None
# 20        M106               None
# 21        M106               None
#
#                                                assets  moreColors  \
# 0   [{'url': '//assets.hermes.com/is/image/hermesp...       False
# 1   [{'url': '//assets.hermes.com/is/image/hermesp...       False
# 2   [{'url': '//assets.hermes.com/is/image/hermesp...       False
# 3   [{'url': '//assets.hermes.com/is/image/hermesp...       False
# 4   [{'url': '//assets.hermes.com/is/image/hermesp...       False
# ..                                                ...         ...
# 17  [{'url': '//assets.hermes.com/is/image/hermesp...       False
# 18  [{'url': '//assets.hermes.com/is/image/hermesp...       False
# 19  [{'url': '//assets.hermes.com/is/image/hermesp...       False
# 20  [{'url': '//assets.hermes.com/is/image/hermesp...       False
# 21  [{'url': '//assets.hermes.com/is/image/hermesp...       False
#
#            size massVolume         avgColor departmentCode  ...  price  \
# 0            48       None        colorless              B  ...  520.0
# 1   SANS_TAILLE       None  beige / natural              S  ...  880.0
# 2   SANS_TAILLE       None              red              S  ...  345.0
# 3          35.5       None            white              Z  ...  600.0
# 4            35       None            black              Z  ...  690.0
# ..          ...        ...              ...            ...  ...    ...
# 17  SANS_TAILLE       None  beige / natural              M  ...  395.0
# 18  SANS_TAILLE       None  beige / natural              M  ...  420.0
# 19  SANS_TAILLE       None             pink              M  ...  360.0
# 20  SANS_TAILLE       None             pink              M  ...  250.0
# 21  SANS_TAILLE       None             pink              M  ...  550.0
#
#                                                   url  \
# 0     /product/osmose-ring-large-model-H102536Bv00048
# 1   /product/couvertures-et-tenues-de-jour-bandana...
# 2        /product/plumes-en-fete-scarf-90-H003433Sv04
# 3                /product/amica-sandal-H201134Zv90355
# 4                 /product/oran-sandal-H201158Zv02350
# ..                                                ...
# 17       /product/adada-dots-baby-bunting-H103140Mv03
# 18       /product/adada-dots-sleeping-bag-H103139Mv03
# 19      /product/cheval-a-bascule-blanket-H103135Mv01
# 20   /product/adada-dots-case-large-model-H103163Mv01
# 21            /product/adada-dots-blanket-H103136Mv01
#
#                                                slug hasStock hasStockRetail  \
# 0                           osmose-ring-large-model     True          False
# 1   couvertures-et-tenues-de-jour-bandana-shawl-140     True          False
# 2                           plumes-en-fete-scarf-90     True          False
# 3                                      amica-sandal     True          False
# 4                                       oran-sandal     True          False
# ..                                              ...      ...            ...
# 17                          adada-dots-baby-bunting     True          False
# 18                          adada-dots-sleeping-bag     True          False
# 19                         cheval-a-bascule-blanket     True          False
# 20                      adada-dots-case-large-model     True          False
# 21                               adada-dots-blanket     True          False
#
#     hasStockOrHasStockRetail  personalize  stock.ecom  stock.retail  catagory
# 0                      False        False        True         False      name
# 1                      False        False        True         False      name
# 2                      False        False        True         False      name
# 3                      False        False        True         False      name
# 4                      False        False        True         False      name
# ..                       ...          ...         ...           ...       ...
# 17                     False        False        True         False      name
# 18                     False        False        True         False      name
# 19                     False        False        True         False      name
# 20                     False        False        True         False      name
# 21                     False        False        True         False      name
#
# [9695 rows x 22 columns]

# %%
df_final.sample(10)
# Out:
#                                            sku  \
# 6                                  H074232CKI7
# 21                              H201439ZH12410
# 7                                  W036702WW00
# 4   U_BELT_32_HOMME-H064550CC06-H073967CAAC090
# 13                              H192512ZHV2440
# 16                                 H064983CD78
# 16                               H110415FPA365
# 26                                 H077698CJAG
# 0                                  H433466T 15
# 30                              H073651CKAK105
#
#                                                 title productCode  \
# 6                        Ulysse Neo PM notebook cover        A012
# 21                                      Irving loafer        Z861
# 7                           Heure H watch, 21 x 21 mm        WHH_
# 4   H Strie belt buckle & Reversible leather strap...        None
# 13                                     Velvet sneaker        Z864
# 16                              Constance long wallet        A021
# 16                       Brides de Gala Shadow bangle        F021
# 26                            In-the-Loop mini wallet        A021
# 0              Chevaux d'Apparat losange, large model        T253
# 30                      Sangle Cavale 50 mm bag strap        C063
#
#    perso_product_type                                             assets  \
# 6                None  [{'url': '//assets.hermes.com/is/image/hermesp...
# 21               None  [{'url': '//assets.hermes.com/is/image/hermesp...
# 7                None  [{'url': '//assets.hermes.com/is/image/hermesp...
# 4                None  [{'url': '//assets.hermes.com/is/image/hermesp...
# 13               None  [{'url': '//assets.hermes.com/is/image/hermesp...
# 16               None  [{'url': '//assets.hermes.com/is/image/hermesp...
# 16               None  [{'url': '//assets.hermes.com/is/image/hermesp...
# 26               None  [{'url': '//assets.hermes.com/is/image/hermesp...
# 0                None  [{'url': '//assets.hermes.com/is/image/hermesp...
# 30               None  [{'url': '//assets.hermes.com/is/image/hermesp...
#
#    moreColors         size massVolume   avgColor departmentCode  ...    price  \
# 6       False  SANS_TAILLE       None       blue              A  ...    415.0
# 21      False           41       None       blue              Z  ...    880.0
# 7       False  SANS_TAILLE       None  colorless              W  ...   2060.0
# 4       False  SANS_TAILLE       None     yellow           None  ...    710.0
# 13      False           44       None       blue              Z  ...    630.0
# 16      False  SANS_TAILLE       None       blue              A  ...  11600.0
# 16      False           65       None      brown              F  ...    455.0
# 26      False  SANS_TAILLE       None       blue              A  ...    860.0
# 0       False  SANS_TAILLE       None       blue              T  ...    540.0
# 30      False          105       None     orange              C  ...    790.0
#
#                                                   url  \
# 6   /product/ulysse-neo-pm-notebook-cover-H074232CKI7
# 21              /product/irving-loafer-H201439ZH12410
# 7        /product/heure-h-watch-21-x-21mm-W036702WW00
# 4   /product/h-strie-belt-buckle-and-reversible-le...
# 13             /product/velvet-sneaker-H192512ZHV2440
# 16         /product/constance-long-wallet-H064983CD78
# 16  /product/brides-de-gala-shadow-bangle-H110415F...
# 26       /product/in-the-loop-mini-wallet-H077698CJAG
# 0   /product/chevaux-d-apparat-losange-large-model...
# 30  /product/sangle-cavale-50-mm-bag-strap-H073651...
#
#                                                  slug hasStock hasStockRetail  \
# 6                        ulysse-neo-pm-notebook-cover     True          False
# 21                                      irving-loafer     True          False
# 7                             heure-h-watch-21-x-21mm     True          False
# 4   h-strie-belt-buckle-and-reversible-leather-str...     True          False
# 13                                     velvet-sneaker     True          False
# 16                              constance-long-wallet     True          False
# 16                       brides-de-gala-shadow-bangle     True          False
# 26                            in-the-loop-mini-wallet     True          False
# 0               chevaux-d-apparat-losange-large-model     True          False
# 30                      sangle-cavale-50-mm-bag-strap     True          False
#
#    hasStockOrHasStockRetail personalize stock.ecom stock.retail  \
# 6                     False       False       True        False
# 21                    False       False       True        False
# 7                     False       False       True        False
# 4                     False       False       True        False
# 13                    False       False       True        False
# 16                    False       False       True        False
# 16                    False       False       True        False
# 26                    False       False       True        False
# 0                     False       False       True        False
# 30                    False       False       True        False
#
#                   pimCode
# 6          READINGWRITING
# 21                    MEN
# 7                 WATCHES
# 4                     MEN
# 13                  SHOES
# 16  BAGSSMALLLEATHERGOODS
# 16                JEWELRY
# 26                    MEN
# 0          SILKSCARVESETC
# 30                  WOMEN
#
# [10 rows x 22 columns]

# %%
def flatten(data,list_col):
    for column in list_col:
        flattened=pd.DataFrame(dict(data[column])).T
        columns=[str(col) for col in flattened.columns]
        flattened.columns=[column + '_' + col for col in columns]
        data=pd.concat([data,flattened], axis=1)
        data=data.drop(column,axis=1)
    return data
